# %% [markdown]
# Usando la base SPAC del año 2023, responderemos algunas preguntas como:
# ## 5. Razón de pérdida de superficie y Afectación en la producción
# + Preguntas: ¿Cuáles son las principales razones de pérdida de superficie agrícola? ¿Qué tipo de condiciones climáticas o plagas afectan más la producción?
#     + Valor para el mercado: Identificar los principales riesgos agrícolas permite implementar seguros agrícolas y desarrollar mejores prácticas de manejo de riesgos, optimizando así la resiliencia del negocio.

# %%
import pandas as pd
import pyreadstat
import os

# %%
os.chdir('C:/ESPAC')

# %%
dt, meta = pyreadstat.read_sav('DATA/USING/cpnac2023.sav')
dt.head()
# Out:
#        Identificador ual_prov ual_estr ual_segm al_ncues  cp_numt  cp_numl  \
# 0  01055201021250001       01       01    02125     0001      1.0      1.0
# 1  01055201021250002       01       01    02125     0002      1.0      1.0
# 2  01055201021250002       01       01    02125     0002      2.0      2.0
# 3  01056101024340004       01       01    02434     0004      3.0      1.0
# 4  01055201029870002       01       01    02987     0002      1.0      1.0
#
#    rc_clacul  cp_k404  cp_k405  ...  edad3  cp_vcomún  cp_vmejorada  \
# 0      478.0      1.0      NaN  ...    NaN       1.00           NaN
# 1      472.0      1.0      NaN  ...    NaN       0.12           NaN
# 2      478.0      1.0      NaN  ...    NaN       0.75           NaN
# 3      472.0      1.0      NaN  ...    NaN        NaN          0.06
# 4      445.0      1.0      NaN  ...    0.1       0.10           NaN
#
#    cp_vhibrinacio  cp_vhibrinterna  cp_sriego  cp_sufertilizantes  \
# ...

# %%
# Mostrar la metadata
print(meta.column_names)
print(meta.column_labels)
# Out:
# ['Identificador', 'ual_prov', 'ual_estr', 'ual_segm', 'al_ncues', 'cp_numt', 'cp_numl', 'rc_clacul', 'cp_k404', 'cp_k405', 'cp_k406', 'cp_distancia_1', 'cp_distancia_2', 'cp_k408', 'cp_k409ha', 'cp_k410ha', 'cp_k411ha', 'cp_k412', 'cp_k416', 'cp_k417', 'cp_k418', 'cp_k420', 'cp_afecta_prod', 'cp_k422', 'cp_k423', 'cp_k424', 'cp_k426', 'cp_venmernac', 'cp_venmerint', 'cp_rdproven1', 'cp_rdproven2', 'cp_rdproven3', 'cp_rdproven4', 'cp_rdproven5', 'cp_rdproven6', 'cp_sdrenaje', 'cp_psdrenaje', 'cp_riego', 'cp_superf_regada_ha', 'cp_porc_surc', 'cp_porc_aspe', 'cp_porc_micr', 'cp_porc_gote', 'cp_porc_nebu', 'cp_porc_otro', 'cp_aferti', 'cp_forg', 'cp_abono_fo', 'cp_cant1_fo', 'cp_umed1_fo', 'cp_abono_liq', 'cp_cant3_fo', 'cp_umed3_fo', 'cp_fqui', 'cp_abono_npk_fq', 'cp_cantidad_npk_fq', 'cp_umed_npk_fq', 'cp_abono_nit_fq', 'cp_cantidad_nit_fq', 'cp_umed_nit_fq', 'cp_abono_fq', 'cp_cantidad_fq', 'cp_umed_fq', 'cp_abono_pot_fq', 'cp_cantidad_pot_fq', 'cp_umed_pot_fq', 'cp_afito', 'cp_porg'
# ...

# %% [markdown]
# # Razón de pérdida superficie_campo (cp_k412)
# Con la finalidad de responder la principal causa de pérdida agrícola
